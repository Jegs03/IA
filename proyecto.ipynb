# %%
#!pip install pyAgrum

# %%
from MineAgent import*
import utils
from minesweeper_mod import *

# %%
k=MineSweeper.beginner()
# Create agent
agent = MineSweeper_Agent()
# Create episode
episodio = utils.Episode(environment=k,\
        agent=agent,\
        model_name='Reglas',\
        num_rounds=100)
# Visualize
episodio.renderize()

# %%
j=MineSweeper.beginner()
j.see_mat()
print(j.see_mat)
j.calc_frontera()
print(j.frontera)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1852\3191806322.py in <module>
#       1 j=MineSweeper.beginner()
# ----> 2 j.see_mat()
#       3 print(j.see_mat)
#       4 j.calc_frontera()
#       5 print(j.frontera)
#
# TypeError: 'NoneType' object is not callable

# %%
j._click_square(0,0)
j.calc_frontera()
print(j.see_mat)
print(j.frontera)
plt.show()
